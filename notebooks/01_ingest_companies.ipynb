# %% [markdown]
# # 01 - Ingest Base Dataset
# Load the core Nepali news CSV (renamed template slot from companies).

# %%
import pandas as pd
df = pd.read_csv('../data/raw/np20ng.csv')
df[['heading', 'source']].head()
