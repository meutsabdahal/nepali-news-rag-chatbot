# %% [markdown]
# # 03 - Build Vector Store
# Generate embeddings and persist the FAISS index.

# %%
from nepali_news_rag.config import get_settings
from nepali_news_rag.index_builder import build_faiss_index
settings = get_settings()
build_faiss_index(chunks, settings.embedding_model, str(settings.vector_store_dir))
