# %% [markdown]
# # 02 - Ingest Price History (Template Placeholder)
# This notebook is retained for structure parity; SQL/price ingestion is out of current scope.

# %%
print('RAG-only scope: price history ingestion is intentionally disabled.')
