# %% [markdown]
# # 04 - Ingest IPOs (Template Placeholder)
# This notebook is retained for structure parity; IPO ingestion is out of current scope.

# %%
print('RAG-only scope: IPO ingestion is intentionally disabled.')
