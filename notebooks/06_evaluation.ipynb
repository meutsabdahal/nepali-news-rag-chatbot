# %% [markdown]
# # 06 - Evaluation
# Run benchmark prompts through the RAG pipeline and inspect route outcomes.

# %%
import json
from nepali_news_rag.pipeline import NepaliNewsPipeline
bench = json.load(open('../evaluation/benchmark_questions.json', encoding='utf-8'))
pipe = NepaliNewsPipeline()
[pipe.run(item['question']) for item in bench]
