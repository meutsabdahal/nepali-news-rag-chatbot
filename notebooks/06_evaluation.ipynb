# %% [markdown]
# # 06 - End-to-End Evaluation
# Run benchmark prompts and inspect route and citation quality.

# %%
import json
from nepali_news_rag.pipeline import NepaliNewsPipeline
bench = json.load(open('../evaluation/benchmark_questions.json'))
pipe = NepaliNewsPipeline()
[pipe.run(item['question']) for item in bench[:2]]
