# %% [markdown]
# # 05 - Ingest News
# Validate and prepare Nepali news chunks for vector indexing.

# %%
import pandas as pd
from nepali_news_rag.data_prep import validate_dataframe, build_chunks
df = pd.read_csv('../data/raw/np20ng.csv')
validated = validate_dataframe(df)
chunks = build_chunks(validated)
len(chunks)
