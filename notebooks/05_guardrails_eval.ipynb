# %% [markdown]
# # 05 - Guardrails Evaluation
# Evaluate prediction/refusal guardrail behavior.

# %%
from nepali_news_rag.guardrails import evaluate_guardrails
evaluate_guardrails('Can you predict next year politics?', 'English')
