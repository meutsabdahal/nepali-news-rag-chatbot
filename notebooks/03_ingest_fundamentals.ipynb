# %% [markdown]
# # 03 - Ingest Fundamentals (Template Placeholder)
# This notebook is retained for structure parity; fundamentals ingestion is out of current scope.

# %%
print('RAG-only scope: fundamentals ingestion is intentionally disabled.')
