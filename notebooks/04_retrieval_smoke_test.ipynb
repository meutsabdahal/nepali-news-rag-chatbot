# %% [markdown]
# # 04 - Retrieval Smoke Test
# Run a few retrieval checks before full chat pipeline execution.

# %%
from nepali_news_rag.config import get_settings
from nepali_news_rag.retriever import Retriever
r = Retriever(get_settings())
docs = r.retrieve('नेपालको शिक्षा समाचार', k=3)
[d.metadata for d in docs]
